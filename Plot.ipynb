# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

import numpy as np
from ipywidgets import interact, FloatSlider
from tkinter import simpledialog
from IPython.display import display, Math, Latex


def divisor_size(dim):
    if dim in range(1, 4):
        return 2
    elif dim in range(4, 10):
        return 5


def format_e_with_subscript(dim_index):
    subscripts = {
        '0': '\u2080',
        '1': '\u2081',
        '2': '\u2082',
        '3': '\u2083',
        '4': '\u2084',
        '5': '\u2085',
        '6': '\u2086',
        '7': '\u2087',
        '8': '\u2088',
        '9': '\u2089'
    }

    if dim_index == 0:
        return "E"
    else:
        subscript = ''.join(subscripts[d] for d in str(dim_index))
        return f"E{subscript}"


def plot_heatmap_nd(**kwargs):
    # Extract slider values
    slider_values = {k: v for k, v in kwargs.items() if k.startswith('alpha_')}

    # Extract indices from slider values
    indices = []
    for dim in sorted(slider_values.keys(), key=lambda x: int(x.split('_')[1])):
        alpha_val = slider_values[dim]
        dim_index = int(dim.split('_')[1])
        dim_vals = np.linspace(0, 1, sign_data.shape[dim_index])
        index = np.argmin(np.abs(dim_vals - alpha_val))
        indices.append(index)

    # Slice the matrices using the indices and ellipsis for the last two dimensions
    sign_matrix = sign_data[tuple(indices) + (Ellipsis,)]
    div_matrix = div_data[tuple(indices) + (Ellipsis,)]

    norm = colors.TwoSlopeNorm(vmin=min_plot_value, vcenter=0, vmax=max_plot_value)

    plt.imshow(sign_matrix, cmap='RdYlGn', norm=norm, extent=[0, 1, 1, 0])
    plt.xticks(np.linspace(0,1,11))
    plt.yticks(np.linspace(0,1,21))

    if annotate_divisors == True:
        rows, cols = sign_matrix.shape
        for m in range(rows):
            for n in range(cols):
                val = div_matrix[m, n]
                for k in range(size_of_matrix + 2):
                    if str(k) == str(val):
                        x = (n + 0.5) / (cols)
                        y = (m + 0.5) / (rows)
                        plt.text(x, y, f"{int(val)}", color=ray_color_list[k], ha="center", va="center", fontsize=divisor_size(dimensions))

    # Create title string
    title_parts = []
    for dim in sorted(slider_values.keys(), key=lambda x: int(x.split('_')[1])):
        alpha_val = slider_values[dim]
        dim_index = int(dim.split('_')[1])
        if dim_index == 0:
            H_part = f"{round(alpha_val, 4)}·H − "
            title_parts.append(H_part)
        else:
            formatted = format_e_with_subscript(dim_index)
            title_parts.append(f"{round(alpha_val, 4)}·" + formatted + " − ")
    title_str = f'α = {" ".join(title_parts)}'
    plt.title(title_str)
    plt.xlabel(f"α_{chr(97 + len(slider_values) + 1)}")  # Last dimension
    plt.ylabel(f"α_{chr(97 + len(slider_values))}")      # Second last dimension

    fig_color = plt.colorbar(ticks=np.linspace(min_plot_value, max_plot_value, 10))
    plt.show()


def plot_func_nd(size_of_matrix, num_dimensions):
    step_counter = 1 / (size_of_matrix - 1)
    sliders = {}

    # Create sliders for all but the last two dimensions
    for dim in range(num_dimensions - 2):
        slider_name = f"alpha_{dim}"  # a, b, c, etc.
        sliders[slider_name] = FloatSlider(
            value=0.5,
            min=0,
            max=1,
            step=step_counter,
            description=f"α_{chr(97 + dim)}"
        )

    interact(plot_heatmap_nd, **sliders)


def computed_examples_name(int_input):
    if int_input == 0:
        return 'CSCKBlP20PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 0\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 1:
        return 'CSCKBlP21PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 1\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 2:
        return 'CSCKBlP22PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 2\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 3:
        return 'CSCKBlP23PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 3\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 4:
        return 'CSCKBlP24PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 4\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 5:
        return 'CSCKBlP25PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 5\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 6:
        return 'CSCKBlP26PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 6\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 7:
        return 'CSCKBlP1xP10PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 0\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 8:
        return 'CSCKBlP1xP11PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 1\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 9:
        return 'CSCKBlP1xP12PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 2\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 10:
        return 'CSCKBlP1xP13PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 3\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 11:
        return 'CSCKBlP1xP14PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 4\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 12:
        return 'CSCKBlP1xP15PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 5\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 13:
        return 'CSCKBlHirzebruch20PointsInfo', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;0\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 14:
        return 'CSCKBlHirzebruch21PointsInfo', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;1\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 15:
        return 'CSCKBlHirzebruch22PointsInfo', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;2\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 16:
        return 'CSCKBlHirzebruch23PointsInfo', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;3\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 17:
        return 'CSCKBlHirzebruch24PointsInfo', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;4\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 18:
        return 'CSCKBlHirzebruch25PointsInfo', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;5\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 19:
        return 'JeqBlP22PointsInfo', '\\text{J-eq}\\;\\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\ 2\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 20:
        return 'JeqBlP23PointsInfo', '\\text{J-eq}\\;\\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\ 3\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 21:
        return 'JeqBlP1xP11PointsInfo', '\\text{J-eq}\\;\\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\; \\text{in}\\ 1\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 22:
        return 'JeqBlP23PointsInfo4Bea0333b05c075d0333', ''
    elif int_input == 23:
        return 'JeqBlP21PointsInfo', '\\text{J-eq}\\;\\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\ 1\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 24:
        return 'JeqBlP21PointsInfo', '\\text{J-eq}\\;\\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\ 1\\;\\text{points},\\;\\text{file index:}\\;'


def computed_examples_indices(ind):
    indices = {
        0: 'None',
        1: '0 - 2',
        2: '0 - 8',
        3: '0 - 18',
        4: '0 - 20',
        5: '0 - 20',
        6: '0 - 4',
        7: '0',
        8: '0 - 3',
        9: '0 - 13',
        10: '0 - 19',
        11: '0 - 20',
        12: '0 - 3',
        13: '0',
        14: '0 - 1',
        15: '0 - 4',
        16: '0 - 5',
        17: '0 - 7',
        18: '0 - 1',
        19: '0, 2, 5, 7-8',
        20: '0, 1, 4',
        21: '3',
        22: '4',
        23: '2',
        24: '2'
    }

    return indices.get(ind)


general_file = int(simpledialog.askstring(
    "Which fan 'Type' do you wish to see?",
    f"0: P2 in 0 points,             indices computed ({computed_examples_indices(0)})"
    f"\n1: P2 in 1 points,             indices computed ({computed_examples_indices(1)})"
    f"\n2: P2 in 2 points,             indices computed ({computed_examples_indices(2)})"
    f"\n3: P2 in 3 points,             indices computed ({computed_examples_indices(3)})"
    f"\n4: P2 in 4 points,             indices computed ({computed_examples_indices(4)})"
    f"\n5: P2 in 5 points,             indices computed ({computed_examples_indices(5)})"
    f"\n6: P2 in 6 points,             indices computed ({computed_examples_indices(6)})"
    f"\n7: P1xP1 in 0 points,          indices computed ({computed_examples_indices(7)})"
    f"\n8: P1xP1 in 1 points,          indices computed ({computed_examples_indices(8)})"
    f"\n9: P1xP1 in 2 points,          indices computed ({computed_examples_indices(9)})"
    f"\n10: P1xP1 in 3 points,          indices computed ({computed_examples_indices(10)})"
    f"\n11: P1xP1 in 4 points,         indices computed ({computed_examples_indices(11)})"
    f"\n12: P1xP1 in 5 points,         indices computed ({computed_examples_indices(12)})"
    f"\n13: Hirzebruch 2 in 0 points,  indices computed ({computed_examples_indices(13)})"
    f"\n14: Hirzebruch 2 in 1 points,  indices computed ({computed_examples_indices(14)})"
    f"\n15: Hirzebruch 2 in 2 points,  indices computed ({computed_examples_indices(15)})"
    f"\n16: Hirzebruch 2 in 3 points,  indices computed ({computed_examples_indices(16)})"
    f"\n17: Hirzebruch 2 in 4 points,  indices computed ({computed_examples_indices(17)})"
    f"\n18: Hirzebruch 2 in 5 points,  indices computed ({computed_examples_indices(18)})"
    f"\n19: J-eq P2 in 2 points        indices computed ({computed_examples_indices(19)})"
    f"\n20: J-eq P2 in 3 points        indices computed ({computed_examples_indices(20)})"
    f"\n21: J-eq P1xP1 in 1 points     indices computed ({computed_examples_indices(21)})"
    f"\n22: J-eq P2 in 3 points not antican indices computed ({computed_examples_indices(22)})"
    f"\n23: J-eq P2 in 1 points        indices computed ({computed_examples_indices(23)})"
    f"\n24: J-eq P2 in 1 points        indices computed ({computed_examples_indices(24)})"
))



general_file_name, latex_info = computed_examples_name(general_file)

index_of_file = str(simpledialog.askstring(
    "Which fan do you wish to see?",
    "Enter the index according to the LaTeX document"
    f"\nIndices computed {computed_examples_indices(general_file)}"
))

beta_coeffs_a = str(simpledialog.askstring(
    "What coefficients of beta you wish to see?",
    "Enter the fraction values of a for beta"
))


beta_coeffs_b = str(simpledialog.askstring(
    "What coefficients of beta you wish to see?",
    "Enter the fraction values of b for beta"
))

display(Math(fr'{latex_info}{index_of_file}'))
if general_file_name[0] == 'J' and general_file_name[-1:] == 'o':
    try:
        sign_data = np.load(f'JeqResults/{general_file_name}{index_of_file}Be{beta_coeffs_a}a{beta_coeffs_b}b.npy.SignData.npy', allow_pickle=True)
        div_data = np.load(f'JeqResults/{general_file_name}{index_of_file}Be{beta_coeffs_a}a{beta_coeffs_b}b.npy.DivData.npy', allow_pickle=True)
        info = np.load(f'Info/Jeq{general_file_name[3:]}{index_of_file}Be{beta_coeffs_a}a{beta_coeffs_b}b.npy', allow_pickle=True)
    except:
        sign_data = np.load(f'JeqResults/{general_file_name}{index_of_file}BetaAntiCan.npy.SignData.npy', allow_pickle=True)
        div_data = np.load(f'JeqResults/{general_file_name}{index_of_file}BetaAntiCan.npy.DivData.npy', allow_pickle=True)
        info = np.load(f'Info/CSCK{general_file_name[3:]}{index_of_file}.npy', allow_pickle=True)

elif general_file_name[0] == 'J' and general_file_name[-1:] == '3':
    sign_data = np.load(f'JeqResults/{general_file_name}.npy.SignData.npy', allow_pickle=True)
    div_data = np.load(f'JeqResults/{general_file_name}.npy.DivData.npy', allow_pickle=True)
    info = np.load(f'Info/JeqBlP23PointsInfo4Bea0333b05c075d0333.npy', allow_pickle=True)
else:
    sign_data = np.load(f'ResultsOfInterest/{general_file_name}{index_of_file}.npy.SignData.npy', allow_pickle=True)
    div_data = np.load(f'ResultsOfInterest/{general_file_name}{index_of_file}.npy.DivData.npy', allow_pickle=True)
    info = np.load(f'Info/{general_file_name}{index_of_file}.npy', allow_pickle=True)
antican_info = info[1]

ray_color_list = []
size_of_matrix = len(sign_data)
dimensions = len(sign_data.shape)

for i in range(dimensions + 2):
    color = 'black'
    ray_color_list.append(color)

index_positions = np.linspace(0, 1, size_of_matrix)

def display_antican_info(coeff_info):
    antican_indexes = r'\beta = '
    for i in range(dimensions):
        indexes = coeff_info[i]
        if i == 0:
            H_part = f"{round(indexes, 4)}·H − "
            antican_indexes += H_part
        else:
            formatted_str = f"{round(indexes, 4)}·E_{i}" + " − "
            antican_indexes += formatted_str
    antican_indexes = antican_indexes[:-3]

    display(Math(r'\text{Antican info}\colon'))
    display(Math(antican_indexes))


def display_value(type_of_value, val):
    position = np.where(sign_data == val)
    position_list = list(zip(*position))
    value_indexes = r'\alpha = '
    for i in range(dimensions):
        indexes = int(position_list[0][i])
        indexes_pos = index_positions[indexes]
        if i == 0:
            H_part = f"{round(indexes_pos, 4)}·H − "
            value_indexes += H_part
        else:
            formatted_str = f"{round(indexes_pos, 4)}·E_{i}" + " − "
            value_indexes += formatted_str
    value_indexes = value_indexes[:-3]

    display(Math(fr'\text{{{type_of_value}}}=' + f'{round(val, 10)} : '))
    display(Math(value_indexes))


def find_maximum_value(sign_matrix_data, value_check):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)[::-1]
    bool_temp = True
    ind = 0
    while bool_temp:
        if sorted_unique_values[ind] < value_check or (sorted_unique_values[ind] > 0 and sorted_unique_values[ind] != 50000 and sorted_unique_values[ind] != 1000):
            max_value = sorted_unique_values[ind]
            bool_temp = False
        ind += 1

    return max_value


def find_minimum_value(sign_matrix_data, value_check):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)
    bool_temp = True
    ind = 0
    while bool_temp:
        if sorted_unique_values[ind] > value_check:
            min_value = sorted_unique_values[ind]
            bool_temp = False
        ind += 1

    return min_value


def find_closest_antican_value(sign_matrix_data):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)[::-1]
    dist = 1_000
    ind = -1
    for i in range(len(sorted_unique_values)):
        tmp_dist = abs(-1 - sorted_unique_values[i])
        if tmp_dist < dist:
            dist = tmp_dist
            ind = i

    return sorted_unique_values[ind]


def find_unique_divisors(divisor_data, show_count):
    flattened_div_matrix = [val for val in divisor_data.flatten() if val is not None]
    unique_divisors, counts = np.unique(flattened_div_matrix, return_counts=True)
    unique_divisors = unique_divisors[1:]
    counts = counts[1:]
    sorted_indices = np.argsort(unique_divisors)
    sorted_unique_divisors = unique_divisors[sorted_indices]
    sorted_counts = counts[sorted_indices]
    if show_count:
        for div, count in zip(sorted_unique_divisors, sorted_counts):
            count = "{:,}".format(count).replace(',','.')
            display(Math(fr'\text{{Divisor}}: {div}, \text{{Count}}: {count}'))

    return sorted_unique_divisors, sorted_counts

def display_min_value(check_value):
    min_value = find_minimum_value(sign_data, check_value)
    display_value("Minimum value", min_value)


def display_max_value(check_value):
    max_value_sign_data = find_maximum_value(sign_data, check_value)
    display_value("Maximum value", max_value_sign_data)


def display_antican_value():
    antican_value = find_closest_antican_value(sign_data)
    display_value("Antican value", antican_value)


def check_positive_areas(sign_matrix_data):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)[::-1]
    dist = 1_000
    ind = -1
    for i in range(len(sorted_unique_values)):
        tmp_dist = abs(sorted_unique_values[i])
        if tmp_dist < dist:
            dist = tmp_dist
            ind = i
    if ind < 5:
        min_ind = 0
    else:
        min_ind = ind - 5
    tmp = list(sorted_unique_values[min_ind: ind])
    for val in list(sorted_unique_values[ind : ind + 5]):
        tmp.append(val)
    temp = []
    for i in range(len(tmp)):
        temp.append(float(tmp[i]))
    for j in range(len(temp)):
        if temp[j] == sorted_unique_values[ind]:
           display_value("Center", temp[j])
        else:
            display_value("TEST", temp[j])


min_plot_value = -4
max_plot_value = 1

check_for_max_value = 0
check_for_min_value = -100_000_000_000_000_000

annotate_divisors = True

check_positive_areas(sign_data)

display_antican_info(antican_info)
display_antican_value()
display_min_value(check_for_min_value)
display_max_value(check_for_max_value)
unique_divs, div_counts = find_unique_divisors(div_data, True)
plot_func_nd(size_of_matrix, dimensions)

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

import numpy as np
from ipywidgets import interact, FloatSlider
from tkinter import simpledialog
from IPython.display import display, Math, Latex


def divisor_size(dim):
    if dim in range(1, 4):
        return 2
    elif dim in range(4, 10):
        return 5


def format_e_with_subscript(dim_index):
    subscripts = {
        '0': '\u2080',
        '1': '\u2081',
        '2': '\u2082',
        '3': '\u2083',
        '4': '\u2084',
        '5': '\u2085',
        '6': '\u2086',
        '7': '\u2087',
        '8': '\u2088',
        '9': '\u2089'
    }

    if dim_index == 0:
        return "E"
    else:
        subscript = ''.join(subscripts[d] for d in str(dim_index))
        return f"E{subscript}"


def plot_heatmap_nd(**kwargs):
    # Extract slider values
    slider_values = {k: v for k, v in kwargs.items() if k.startswith('alpha_')}

    # Extract indices from slider values
    indices = []
    for dim in sorted(slider_values.keys(), key=lambda x: int(x.split('_')[1])):
        alpha_val = slider_values[dim]
        dim_index = int(dim.split('_')[1])
        dim_vals = np.linspace(0, 1, sign_data.shape[dim_index])
        index = np.argmin(np.abs(dim_vals - alpha_val))
        indices.append(index)

    # Slice the matrices using the indices and ellipsis for the last two dimensions
    sign_matrix = sign_data[tuple(indices) + (Ellipsis,)]
    div_matrix = div_data[tuple(indices) + (Ellipsis,)]

    norm = colors.TwoSlopeNorm(vmin=min_plot_value, vcenter=0, vmax=max_plot_value)

    plt.imshow(sign_matrix, cmap='RdYlGn', norm=norm, extent=[0, 1, 1, 0])

    if annotate_divisors == True:
        rows, cols = sign_matrix.shape
        for m in range(rows):
            for n in range(cols):
                val = div_matrix[m, n]
                for k in range(size_of_matrix + 2):
                    if str(k) == str(val):
                        x = (n + 0.5) / (cols)
                        y = (m + 0.5) / (rows)
                        plt.text(x, y, f"{int(val)}", color=ray_color_list[k], ha="center", va="center", fontsize=divisor_size(dimensions))

    # Create title string
    title_parts = []
    for dim in sorted(slider_values.keys(), key=lambda x: int(x.split('_')[1])):
        alpha_val = slider_values[dim]
        dim_index = int(dim.split('_')[1])
        if dim_index == 0:
            H_part = f"{round(alpha_val, 4)}·H − "
            title_parts.append(H_part)
        else:
            formatted = format_e_with_subscript(dim_index)
            title_parts.append(f"{round(alpha_val, 4)}·" + formatted + " − ")
    title_str = f'α = {" ".join(title_parts)}'
    plt.title(title_str)
    plt.xlabel(f"α_{chr(97 + len(slider_values) + 1)}")  # Last dimension
    plt.ylabel(f"α_{chr(97 + len(slider_values))}")      # Second last dimension

    fig_color = plt.colorbar(ticks=np.linspace(min_plot_value, max_plot_value, 10))
    plt.show()


def plot_func_nd(size_of_matrix, num_dimensions):
    step_counter = 1 / (size_of_matrix - 1)
    sliders = {}

    # Create sliders for all but the last two dimensions
    for dim in range(num_dimensions - 2):
        slider_name = f"alpha_{dim}"  # a, b, c, etc.
        sliders[slider_name] = FloatSlider(
            value=0.5,
            min=0,
            max=1,
            step=step_counter,
            description=f"α_{chr(97 + dim)}"
        )

    interact(plot_heatmap_nd, **sliders)

sign_data = np.load(f'ResultsOfInterest/CSCKBlP21PointsInfo0.npy.SignData.npy', allow_pickle=True)
div_data = np.load(f'ResultsOfInterest/CSCKBlP21PointsInfo0.npy.DivData.npy', allow_pickle=True)
info = np.load(f'Info/CSCKBlP21PointsInfo0.npy', allow_pickle=True)
antican_info = info[1]

ray_color_list = []
size_of_matrix = len(sign_data)
dimensions = len(sign_data.shape)

for i in range(dimensions + 2):
    color = 'black'
    ray_color_list.append(color)

index_positions = np.linspace(0, 1, size_of_matrix)

def display_antican_info(coeff_info):
    antican_indexes = r'\beta = '
    for i in range(dimensions):
        indexes = coeff_info[i]
        if i == 0:
            H_part = f"{round(indexes, 4)}·H − "
            antican_indexes += H_part
        else:
            formatted_str = f"{round(indexes, 4)}·E_{i}" + " − "
            antican_indexes += formatted_str
    antican_indexes = antican_indexes[:-3]

    display(Math(r'\text{Antican info}\colon'))
    display(Math(antican_indexes))


def display_value(type_of_value, val):
    position = np.where(sign_data == val)
    position_list = list(zip(*position))
    value_indexes = r'\alpha = '
    for i in range(dimensions):
        indexes = int(position_list[0][i])
        indexes_pos = index_positions[indexes]
        if i == 0:
            H_part = f"{round(indexes_pos, 4)}·H − "
            value_indexes += H_part
        else:
            formatted_str = f"{round(indexes_pos, 4)}·E_{i}" + " − "
            value_indexes += formatted_str
    value_indexes = value_indexes[:-3]

    display(Math(fr'\text{{{type_of_value}}}=' + f'{round(val, 10)} : '))
    display(Math(value_indexes))


def find_maximum_value(sign_matrix_data, value_check):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)[::-1]
    bool_temp = True
    ind = 0
    while bool_temp:
        if sorted_unique_values[ind] < value_check or (sorted_unique_values[ind] > 0 and sorted_unique_values[ind] != 50000 and sorted_unique_values[ind] != 1000):
            max_value = sorted_unique_values[ind]
            bool_temp = False
        ind += 1

    return max_value


def find_minimum_value(sign_matrix_data, value_check):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)
    bool_temp = True
    ind = 0
    while bool_temp:
        if sorted_unique_values[ind] > value_check:
            min_value = sorted_unique_values[ind]
            bool_temp = False
        ind += 1

    return min_value


def find_closest_antican_value(sign_matrix_data):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)[::-1]
    dist = 1_000
    ind = -1
    for i in range(len(sorted_unique_values)):
        tmp_dist = abs(-1 - sorted_unique_values[i])
        if tmp_dist < dist:
            dist = tmp_dist
            ind = i

    return sorted_unique_values[ind]


def find_unique_divisors(divisor_data, show_count):
    flattened_div_matrix = [val for val in divisor_data.flatten() if val is not None]
    unique_divisors, counts = np.unique(flattened_div_matrix, return_counts=True)
    unique_divisors = unique_divisors[1:]
    counts = counts[1:]
    sorted_indices = np.argsort(unique_divisors)
    sorted_unique_divisors = unique_divisors[sorted_indices]
    sorted_counts = counts[sorted_indices]
    if show_count:
        for div, count in zip(sorted_unique_divisors, sorted_counts):
            count = "{:,}".format(count).replace(',','.')
            display(Math(fr'\text{{Divisor}}: {div}, \text{{Count}}: {count}'))

    return sorted_unique_divisors, sorted_counts

def display_min_value(check_value):
    min_value = find_minimum_value(sign_data, check_value)
    display_value("Minimum value", min_value)


def display_max_value(check_value):
    max_value_sign_data = find_maximum_value(sign_data, check_value)
    display_value("Maximum value", max_value_sign_data)


def display_antican_value():
    antican_value = find_closest_antican_value(sign_data)
    display_value("Antican value", antican_value)


def check_positive_areas(sign_matrix_data):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)[::-1]
    dist = 1_000
    ind = -1
    for i in range(len(sorted_unique_values)):
        tmp_dist = abs(sorted_unique_values[i])
        if tmp_dist < dist:
            dist = tmp_dist
            ind = i
    if ind < 5:
        min_ind = 0
    else:
        min_ind = ind - 5
    tmp = list(sorted_unique_values[min_ind: ind])
    for val in list(sorted_unique_values[ind : ind + 5]):
        tmp.append(val)
    temp = []
    for i in range(len(tmp)):
        temp.append(float(tmp[i]))
    for j in range(len(temp)):
        if temp[j] == sorted_unique_values[ind]:
           display_value("Center", temp[j])
        else:
            display_value("TEST", temp[j])


min_plot_value = -3
max_plot_value = 0.0000000001

check_for_max_value = -1
check_for_min_value = -100_000_000_000_000_000

annotate_divisors = False

check_positive_areas(sign_data)

display_antican_info(antican_info)
display_antican_value()
display_min_value(check_for_min_value)
display_max_value(check_for_max_value)
unique_divs, div_counts = find_unique_divisors(div_data, False)
plot_func_nd(size_of_matrix, dimensions)

# %%
import sys
from io import StringIO
import pyperclip

output_buffer = StringIO()
sys.stdout = output_buffer


def percentages(counts):
    total = sum(counts)
    percentage = []
    for i in range(len(counts)):
        percentage.append(round(counts[i] / total, 3) * 100)

    return percentage


def latex_div_count(unique_divisors, divisors_counts):
    unique_divisors = list(unique_divisors)
    divisors_counts = list(divisors_counts)
    for i in range(len(unique_divisors)):
        unique_divisors[i] = int(unique_divisors[i])
    unique_divisors_true = [0 for _ in range(dimensions + 2)]
    divisors_counts_true = [0 for _ in range(dimensions + 2)]
    for elm in unique_divisors:
        ind = unique_divisors.index(elm)
        divisors_counts_true[elm] = divisors_counts[ind]
        unique_divisors_true[elm] = elm
    for i in range(dimensions + 2):
        if i != unique_divisors_true[i]:
            unique_divisors_true[i] = i
    perc = percentages(divisors_counts_true)
    print(r'\qquad')
    print(r'\begin{array}{|c|c|c|}')
    print(r'    \hline')
    print(r'    & \text{Ocurrences} & \text{Percentages}\\')
    print(r'    \hline')
    for i in range(dimensions + 2):
        print(fr'    D_{{{i}}} & {divisors_counts_true[i]} & {round(perc[i], 1)}\% \\')
    print(r'    \hline')
    print(r'\end{array}')


latex_div_count(unique_divs, div_counts)

sys.stdout = sys.__stdout__

# Copy captured output to clipboard
output = output_buffer.getvalue()
pyperclip.copy(output)

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np
from ipywidgets import interact, FloatSlider
from tkinter import simpledialog
from IPython.display import display, Math, Latex


def format_e_with_subscript(dim_index):
    subscripts = {
        '0': '\u2080',
        '1': '\u2081',
        '2': '\u2082',
        '3': '\u2083',
        '4': '\u2084',
        '5': '\u2085',
        '6': '\u2086',
        '7': '\u2087',
        '8': '\u2088',
        '9': '\u2089'
    }

    if dim_index == 0:
        return "E"
    else:
        subscript = ''.join(subscripts[d] for d in str(dim_index))
        return f"E{subscript}"


def plot_heatmap_nd(**kwargs):
    # Extract slider values
    slider_values = {k: v for k, v in kwargs.items() if k.startswith('alpha_')}

    # Extract indices from slider values
    indices = []
    for dim in sorted(slider_values.keys(), key=lambda x: int(x.split('_')[1])):
        alpha_val = slider_values[dim]
        dim_index = int(dim.split('_')[1])
        dim_vals = np.linspace(0, 1, sign_data.shape[dim_index])
        index = np.argmin(np.abs(dim_vals - alpha_val))
        indices.append(index)

    # Slice the matrices using the indices and ellipsis for the last two dimensions
    sign_matrix = sign_data[tuple(indices) + (Ellipsis,)]
    div_matrix = div_data[tuple(indices) + (Ellipsis,)]

    plt.imshow(sign_matrix, cmap='RdYlGn', vmin=min_plot_value, vmax=max_plot_value, extent=[0, 1, 1, 0])

    rows, cols = sign_matrix.shape
    for m in range(rows):
        for n in range(cols):
            val = div_matrix[m, n]
            for k in range(size_of_matrix + 2):
                if str(k) == str(val):
                    x = (n + 0.5) / (cols)
                    y = (m + 0.5) / (rows)
                    plt.text(x, y, f"{int(val)}", color=ray_color_list[k], ha="center", va="center", fontsize=5)

    # Create title string
    title_parts = []
    for dim in sorted(slider_values.keys(), key=lambda x: int(x.split('_')[1])):
        alpha_val = slider_values[dim]
        dim_index = int(dim.split('_')[1])
        if dim_index == 0:
            H_part = f"{round(alpha_val, 4)}·H − "
            title_parts.append(H_part)
        else:
            formatted = format_e_with_subscript(dim_index)
            title_parts.append(f"{round(alpha_val, 4)}·" + formatted + " − ")
    title_str = f'α = {" ".join(title_parts)}'
    plt.title(title_str)
    plt.xlabel(f"α_{chr(97 + len(slider_values) + 1)}")  # Last dimension
    plt.ylabel(f"α_{chr(97 + len(slider_values))}")      # Second last dimension

    fig_color = plt.colorbar(ticks=np.linspace(min_plot_value, max_plot_value, 10))
    plt.show()


def plot_func_nd(size_of_matrix, num_dimensions):
    step_counter = 1 / (size_of_matrix - 1)
    sliders = {}

    # Create sliders for all but the last two dimensions
    for dim in range(num_dimensions - 2):
        slider_name = f"alpha_{dim}"  # a, b, c, etc.
        sliders[slider_name] = FloatSlider(
            value=0.5,
            min=0,
            max=1,
            step=step_counter,
            description=f"α_{chr(97 + dim)}"
        )

    interact(plot_heatmap_nd, **sliders)


def computed_examples_name(int_input):
    if int_input == 0:
        return 'CSCKBlP23PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 3\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 1:
        return 'CSCKBlP24PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 4\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 2:
        return 'CSCKBlP25PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 5\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 3:
        return 'CSCKBlP26PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 6\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 4:
        return 'CSCKBlP27PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^2\\; \\text{in}\\; 7\\; \\text{points},\\;\\text{file index:}\\;'
    elif int_input == 5:
        return 'CSCKBlP1XP12PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 2\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 6:
        return 'CSCKBlP1XP13PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 3\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 7:
        return 'CSCKBlP1XP14PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 4\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 8:
        return 'CSCKBlP1XP15PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 5\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 9:
        return 'CSCKBlP1XP16PointsInfo', '\\text{CSCK}\\; \\text{blowup of}\\; \\mathbb{P}^1\\times\\mathbb{P}^1\\;\\text{in}\\; 6\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 10:
        return 'CSCKBlHirzebruch12Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=1\\;\\text{in}\\;2\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 11:
        return 'CSCKBlHirzebruch13Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=1\\;\\text{in}\\;3\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 12:
        return 'CSCKBlHirzebruch14Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=1\\;\\text{in}\\;4\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 13:
        return 'CSCKBlHirzebruch15Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=1\\;\\text{in}\\;5\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 14:
        return 'CSCKBlHirzebruch16Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=1\\;\\text{in}\\;6\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 15:
        return 'CSCKBlHirzebruch17Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=1\\;\\text{in}\\;7\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 16:
        return 'CSCKBlHirzebruch22Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;2\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 17:
        return 'CSCKBlHirzebruch23Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;3\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 18:
        return 'CSCKBlHirzebruch24Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;4\\;\\text{points},\\;\\text{file index:}\\;'
    elif int_input == 19:
        return 'CSCKBlHirzebruch25Info', '\\text{CSCK}\\;\\text{blowup of}\\;\\text{Hirzebruch with}\\; r=2\\;\\text{in}\\;5\\;\\text{points},\\;\\text{file index:}\\;'

def computed_examples_indices(ind):
    indices = {
        0: '0 - 27',
        1: '0 - 89',
        2: '0 - 9',
        3: '0 - 9',
        4: '0 - 9',
        5: '0 - 13',
        6: '0, 10 - 12, 14',
        7: '0 - 9',
        8: '0 - 9',
        9: '0 - 9',
        10: '0 - 13',
        11: '0 - 9',
        12: '0 - 9',
        13: '0 - 9',
        14: '0 - 6',
        15: '0 - 1, 10 - 21, 23 - 35',
        16: '0 - 13',
        17: '7 - 9',
        18: '2, 4, 6, 8',
        19: '0',
    }

    return indices.get(ind)


general_file = int(simpledialog.askstring(
    "Which fan 'Type' do you wish to see?",
    f"0: P2 in 3 points,             indices computed ({computed_examples_indices(0)})"
    f"\n1: P2 in 4 points,             indices computed ({computed_examples_indices(1)})"
    f"\n2: P2 in 5 points,             indices computed ({computed_examples_indices(2)})"
    f"\n3: P2 in 6 points,             indices computed ({computed_examples_indices(3)})"
    f"\n4: P2 in 7 points,             indices computed ({computed_examples_indices(4)})"
    f"\n5: P1xP1 in 2 points,          indices computed ({computed_examples_indices(5)})"
    f"\n6: P1xP1 in 3 points,          indices computed ({computed_examples_indices(6)})"
    f"\n7: P1xP1 in 4 points,          indices computed ({computed_examples_indices(7)})"
    f"\n8: P1xP1 in 5 points,          indices computed ({computed_examples_indices(8)})"
    f"\n9: P1xP1 in 6 points,          indices computed ({computed_examples_indices(9)})"
    f"\n10: Hirzerbruch 1 in 2 points, indices computed ({computed_examples_indices(10)})"
    f"\n11: Hirzerbruch 1 in 3 points, indices computed ({computed_examples_indices(11)})"
    f"\n12: Hirzerbruch 1 in 4 points, indices computed ({computed_examples_indices(12)})"
    f"\n13: Hirzerbruch 1 in 5 points, indices computed ({computed_examples_indices(13)})"
    f"\n14: Hirzerbruch 1 in 6 points, indices computed ({computed_examples_indices(14)})"
    f"\n15: Hirzebruch 2 in 2 points,  indices computed ({computed_examples_indices(15)})"
    f"\n16: Hirzebruch 2 in 3 points,  indices computed ({computed_examples_indices(16)})"
    f"\n17: Hirzebruch 2 in 4 points,  indices computed ({computed_examples_indices(17)})"
    f"\n18: Hirzebruch 2 in 5 points,  indices computed ({computed_examples_indices(18)})"
))


general_file_name, latex_info = computed_examples_name(general_file)

index_of_file = str(simpledialog.askstring(
    "Which fan do you wish to see?",
    "Enter the index according to the LaTeX document"
    f"\nIndices computed {computed_examples_indices(general_file)}"
))

display(Math(fr'{latex_info}{index_of_file}'))

sign_data = np.load(f'Results/{general_file_name}{index_of_file}.npy.SignData.npy', allow_pickle=True)
div_data = np.load(f'Results/{general_file_name}{index_of_file}.npy.DivData.npy', allow_pickle=True)

ray_color_list = []
size_of_matrix = len(sign_data)
dimensions = len(sign_data.shape)

for i in range(dimensions + 2):
    color = 'black'
    ray_color_list.append(color)

index_positions = np.linspace(0, 1, size_of_matrix)


def find_maximum_value(sign_matrix_data, value_check):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)[::-1]

    bool_temp = True
    ind = 0
    while bool_temp:
        if sorted_unique_values[ind] < value_check or (sorted_unique_values[ind] > 0 and sorted_unique_values[ind] != 50000 and sorted_unique_values[ind] != 1000):
            max_value = sorted_unique_values[ind]
            bool_temp = False
        ind += 1

    return max_value


def find_minimum_value(sign_matrix_data, value_check):
    flattened_matrix = sign_matrix_data.flatten()
    unique_values = np.unique(flattened_matrix)
    sorted_unique_values = np.sort(unique_values)

    bool_temp = True
    ind = 0
    while bool_temp:
        if sorted_unique_values[ind] > value_check:
            min_value = sorted_unique_values[ind]
            bool_temp = False
        ind += 1

    return min_value


def find_unique_divisors(divisor_data):
    flattened_div_matrix = [val for val in divisor_data.flatten() if val is not None]
    unique_divisors, counts = np.unique(flattened_div_matrix, return_counts=True)
    unique_divisors = unique_divisors[1:]
    counts = counts[1:]
    sorted_indices = np.argsort(unique_divisors)
    sorted_unique_divisors = unique_divisors[sorted_indices]
    sorted_counts = counts[sorted_indices]
    for div, count in zip(sorted_unique_divisors, sorted_counts):
        count = "{:,}".format(count).replace(',','.')
        display(Math(fr'\text{{Divisor}}: {div}, \text{{Count}}: {count}'))

    return sorted_unique_divisors, sorted_counts

def display_min_value(check_value):
    min_value = find_minimum_value(sign_data, check_value)
    min_position = np.where(sign_data == min_value)
    minimum_value = "{:f}".format(round(min_value, 1))
    min_value_indexes = r'\alpha = '
    for i in range(dimensions):
        min_indexes = index_positions[min_position[i][0]]
        if i == 0:
            H_part = f"{round(min_indexes, 4)}·H − "
            min_value_indexes += H_part
        else:
            formatted_str = f"{round(min_indexes, 4)}·E_{i}" + " − "
            min_value_indexes += formatted_str
    min_value_indexes = min_value_indexes[:-3]
    display(Math(r'\text{Minimum value}=' + f'{round(min_value, 4)} : ' + min_value_indexes))


def display_max_value(check_value):
    max_value_sign_data = find_maximum_value(sign_data, check_value)
    max_position = np.where(sign_data == max_value_sign_data)
    maximum_value = "{:f}".format(float(round(max_value_sign_data, 1)))
    max_position_list = list(zip(*max_position))

    max_value_indexes = r'\alpha = '
    for i in range(dimensions):
        max_indexes = int(max_position_list[0][i])
        max_indexes_pos = index_positions[max_indexes]
        if i == 0:
            H_part = f"{round(max_indexes_pos, 4)}·H − "
            max_value_indexes += H_part
        else:
            formatted_str = f"{round(max_indexes_pos, 4)}·E_{i}" + " − "
            max_value_indexes += formatted_str
    max_value_indexes = max_value_indexes[:-3]

    display(Math(r'\text{Maximum value}=' + f'{round(max_value_sign_data, 4)} : ' + max_value_indexes))


min_plot_value = -5
max_plot_value = 0

check_for_max_value = -0.1
check_for_min_value = -100_000_000_000_000_000

display_min_value(check_for_min_value)
display_max_value(check_for_max_value)
unique_divs, div_counts = find_unique_divisors(div_data)
plot_func_nd(size_of_matrix, dimensions)

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import numpy as np
import time
import plotly.graph_objects as go
from ipywidgets import interact, FloatSlider
from functools import lru_cache
from concurrent.futures import ProcessPoolExecutor
from multiprocessing import Pool, cpu_count
from tkinter import simpledialog


def plot_heatmap2d(a_alpha=0.5, b_alpha=0.5):
    # Find nearest α grid indices
    i = np.argmin(np.abs(a_alpha_vals - a_alpha))
    j = np.argmin(np.abs(b_alpha_vals - b_alpha))

    sign_matrix = sign_data[i, j, :, :]
    div_matrix = div_data[i, j, :, :]

    colors_list = ['yellow', '#FF0000', '#FFFFFF', '#15B01A', '#C5C9C7']
    cmap = colors.ListedColormap(colors_list)
    plt.imshow(sign_matrix, cmap='RdYlGn', vmin=min_plot_value, vmax=max_plot_value, extent=[0, 1, 1, 0])

    # Annotate with divisor data
    for m in range(len(a_vals)):
        for n in range(len(b_vals)):
            val = div_matrix[m, n]
            for k in range(number_of_rays):
                if val == str(k):
                    # Compute coordinates for text position
                    x = b_vals[n]
                    y = a_vals[m]
                    # Add text (centered in each cell)
                    plt.text(x, y, f"{val}", color=ray_color_list[k], ha="center", va="center", fontsize=5)

    title_str = f'α = {round(a_alpha, 4)}H - {round(b_alpha, 4)}E_1 - '


    fig_color = plt.colorbar(ticks=np.linspace(min_plot_value, max_plot_value, 10))
    #fig_color.ax.set_yticklabels(['Zero', 'Positive', 'Wall', 'Positive', 'Not in Kc'])
    plt.title(title_str)
    plt.xlabel(f"α_d")
    plt.ylabel(f"α_c")
    plt.show()


def plot_func2d():
    step_counter = 1 / (50 - 1)
    interact(
        plot_heatmap2d,
        a_alpha=FloatSlider(value=0.5, min=0, max=1, step=step_counter, description=f"α_a"),
        b_alpha=FloatSlider(value=0.5, min=0, max=1, step=step_counter, description=f"α_b")
    )


def samples(choice):
    size_input = int(simpledialog.askstring(
            "What size matrix?",
            "Size 25 (decently smooth)\nSize 50 (a little slow)"
        ))

    if choice == 0:
        number_of_rays = 4
        sign_data = np.load(f"BlowUpP2Sigma0SignData{size_input}.npy", allow_pickle=True)
        div_data = np.load(f"BlowUpP2Sigma0DivData{size_input}.npy", allow_pickle=True)
        marker_data = list(np.load(f"BlowUpP2Sigma0MarkerData{size_input}.npy", allow_pickle=True))
        return sign_data, div_data, marker_data, number_of_rays

    elif choice == 1:
        number_of_rays = 4
        sign_data = np.load(f"BlowUpP2Sigma1SignData{size_input}.npy", allow_pickle=True)
        div_data = np.load(f"BlowUpP2Sigma1DivData{size_input}.npy", allow_pickle=True)
        marker_data = list(np.load(f"BlowUpP2Sigma1MarkerData{size_input}.npy", allow_pickle=True))
        return sign_data, div_data, marker_data, number_of_rays

    elif choice == 2:
        number_of_rays = 4
        sign_data = np.load(f"BlowUpP2Sigma2SignData{size_input}.npy", allow_pickle=True)
        div_data = np.load(f"BlowUpP2Sigma2DivData{size_input}.npy", allow_pickle=True)
        marker_data = list(np.load(f"BlowUpP2Sigma2MarkerData{size_input}.npy", allow_pickle=True))
        return sign_data, div_data, marker_data, number_of_rays

def computed_examples_name(int_input):
    if int_input == 0:
        return 'CSCKBlP23PointsInfo'
    elif int_input == 1:
        return 'CSCKBlP1XP12Info'
    elif int_input == 2:
        return 'CSCKBlHirzebruch12Info'
    elif int_input == 3:
        return 'CSCKBlHirzebruch22Info'


def first_choice(user_input):
    if user_input == 0:
        general_file = int(simpledialog.askstring(
            "Which fan 'Type' do you wish to see?",
            "0: P2 in 3 points \n1: P1xP1 in 2 points \n2: Hirzerbruch 1 in 2 points \n3: Hirzebruch 2 in 2 points"
        ))

        general_file_name = computed_examples_name(general_file)

        index_of_file = str(simpledialog.askstring(
            "Which fan do you wish to see?",
            "Enter the index according to the LaTeX document"
        ))

        number_of_rays = int(simpledialog.askstring(
            "How many rays?",
            "Enter the number of rays"
        ))
        print(f"File loaded is {general_file_name[:-4]} {index_of_file}")
        sign_data = np.load(f'Results/{general_file_name}{index_of_file}.npy.SignData.npy', allow_pickle=True)
        div_data = np.load(f'Results/{general_file_name}{index_of_file}.npy.DivData.npy', allow_pickle=True)

        return sign_data, div_data, number_of_rays
    elif user_input == 1:
        choice = int(simpledialog.askstring(
            "Which sample?",
            "0: Blowup of P^2 at Sigma0\n1: Blowup of P^2 at Sigma1\n2: Blowup of P^2 at Sigma2"
        ))

        sign_data, div_data, marker_data, number_of_rays = samples(choice)
        return sign_data, div_data, marker_data, number_of_rays


user_input = int(simpledialog.askstring(
    "Input",
    "Choice 0: Do you wish to load a specific file?\nChoice 1: Choose from known samples?"
))

sign_data, div_data, number_of_rays = first_choice(user_input)



#ray_color_list = ['yellow', 'black', 'white', 'blue', 'green', 'orange', 'black']
ray_color_list = ['black', 'black','black', 'black','black', 'black', 'black']
size_of_matrix = len(sign_data)
a_vals = np.linspace(0, 1, size_of_matrix)
b_vals = np.linspace(0, 1, size_of_matrix)
a_alpha_vals = np.linspace(0, 1, size_of_matrix)
b_alpha_vals = np.linspace(0, 1, size_of_matrix)

min_plot_value = -3
max_plot_value = 1

plot_func2d()
